# %%
# Step 0 installs
# %pip install transformers torch pandas numpy matplotlib networkx seaborn scikit-learn umap-learn ipywidgets

# Step 0: Imports
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity, pairwise_distances
from sklearn.cluster import DBSCAN
import seaborn as sns
import networkx as nx
import os
# Out:
# Requirement already satisfied: transformers in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (4.46.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: torch in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (2.4.1)
# Requirement already satisfied: pandas in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (1.24.4)
# Requirement already satisfied: matplotlib in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (3.7.5)
# Requirement already satisfied: networkx in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (3.1)
# Requirement already satisfied: seaborn in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (1.3.2)
# Requirement already satisfied: umap-learn in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (0.5.7)
# Requirement already satisfied: ipywidgets in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (8.1.8)
# Requirement already satisfied: filelock in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: jinja2 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from torch) (2025.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: numba>=0.51.2 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from umap-learn) (0.58.1)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: comm>=0.1.3 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipywidgets) (8.12.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: backcall in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pickleshare in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: colorama in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: importlib-metadata in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from numba>=0.51.2->umap-learn) (8.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\yalin\anaconda3\envs\dna_embed\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
# Step 1: FASTA file paths (ensure commas between entries)
embedding_files = [r"C:\Users\yalin\OneDrive\Desktop\MRes\A Nosocomial Project\CPE Embedding Nucleotide Test\C_freundii\234098wA8_CPE0002631_assembly_filtered.pt",
r"C:\Users\yalin\OneDrive\Desktop\MRes\A Nosocomial Project\CPE Embedding Nucleotide Test\C_freundii\234098wB12_CPE0002665_assembly_filtered.pt",
r"C:\Users\yalin\OneDrive\Desktop\MRes\A Nosocomial Project\CPE Embedding Nucleotide Test\C_freundii\234098wD4_CPE0002596_assembly_filtered.pt",
r"C:\Users\yalin\OneDrive\Desktop\MRes\A Nosocomial Project\CPE Embedding Nucleotide Test\C_freundii\234098wE9_CPE0002644_assembly_filtered.pt",
r"C:\Users\yalin\OneDrive\Desktop\MRes\A Nosocomial Project\CPE Embedding Nucleotide Test\C_freundii\234098wF3_CPE0002590_assembly_filtered.pt",
r"C:\Users\yalin\OneDrive\Desktop\MRes\A Nosocomial Project\CPE Embedding Nucleotide Test\C_freundii\234098wG2_CPE0002583_assembly_filtered.pt",
r"C:\Users\yalin\OneDrive\Desktop\MRes\A Nosocomial Project\CPE Embedding Nucleotide Test\C_freundii\234098wG4_CPE0002599_assembly_filtered.pt",
r"C:\Users\yalin\OneDrive\Desktop\MRes\A Nosocomial Project\CPE Embedding Nucleotide Test\C_freundii\234099wC1_CPE0002671_assembly_filtered.pt",
r"C:\Users\yalin\OneDrive\Desktop\MRes\A Nosocomial Project\CPE Embedding Nucleotide Test\C_freundii\234099wF2_CPE0002684_assembly_filtered.pt",
r"C:\Users\yalin\OneDrive\Desktop\MRes\A Nosocomial Project\CPE Embedding Nucleotide Test\C_freundii\234099wH4_CPE0002706_assembly_filtered.pt",]

# %%
# Step 2: Load embeddings
headers = []
embeddings = []

for file_path in embedding_files:
    try:
        emb = torch.load(file_path)
        if torch.is_tensor(emb):
            emb = emb.numpy()
        headers.append(os.path.basename(file_path))
        embeddings.append(emb)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Step 3: Create dataframe
df_all = pd.DataFrame({
    'Header': headers,
    'embedding': embeddings
})

# Step 4: Extract headers and embeddings
headers = []
embeddings = []

for file_path in embedding_files:
    try:
        emb = torch.load(file_path, weights_only=True)
        if torch.is_tensor(emb) and emb.ndim == 1:
            headers.append(os.path.basename(file_path))
            embeddings.append(emb.numpy())
        else:
            print(f"Skipped {file_path}: not a 1D tensor")
    except Exception as e:
        print(f"Error processing {file_path}: {e}")


# Step 5: Create dataframe
df_all = pd.DataFrame({
    'Header': headers,
    'embedding': embeddings
})

X = np.stack(df_all['embedding'].values)

# Step 6: Cosine similarity matrix
X = np.stack(df_all['embedding'].values)
similarity_matrix = cosine_similarity(X)

# Step 7: Print cosine similarity values
print("Cosine Similarity Matrix:\n")
for i in range(len(df_all)):
    for j in range(len(df_all)):
        label_i = df_all['Header'][i]
        label_j = df_all['Header'][j]
        sim = similarity_matrix[i][j]
        print(f"{label_i} vs {label_j}: {sim:.4f}")
# Out:
# Cosine Similarity Matrix:
#
# 234098wA8_CPE0002631_assembly_filtered.pt vs 234098wA8_CPE0002631_assembly_filtered.pt: 1.0000
# 234098wA8_CPE0002631_assembly_filtered.pt vs 234098wB12_CPE0002665_assembly_filtered.pt: 0.9995
# 234098wA8_CPE0002631_assembly_filtered.pt vs 234098wD4_CPE0002596_assembly_filtered.pt: 0.9998
# 234098wA8_CPE0002631_assembly_filtered.pt vs 234098wE9_CPE0002644_assembly_filtered.pt: 0.9996
# 234098wA8_CPE0002631_assembly_filtered.pt vs 234098wF3_CPE0002590_assembly_filtered.pt: 0.9998
# 234098wA8_CPE0002631_assembly_filtered.pt vs 234098wG2_CPE0002583_assembly_filtered.pt: 0.9998
# 234098wA8_CPE0002631_assembly_filtered.pt vs 234098wG4_CPE0002599_assembly_filtered.pt: 0.9998
# 234098wA8_CPE0002631_assembly_filtered.pt vs 234099wC1_CPE0002671_assembly_filtered.pt: 0.9998
# 234098wA8_CPE0002631_assembly_filtered.pt vs 234099wF2_CPE0002684_assembly_filtered.pt: 0.9998
# 234098wA8_CPE0002631_assembly_filtered.pt vs 234099wH4_CPE0002706_assembly_filtered.pt: 0.9999
# 234098wB12_CPE0002665_assembly_filtered.pt vs 234098wA8_CPE0002631_assembly_filtered.pt: 0.9995
# 234098wB12_CPE0002665_assembly_filtered.pt vs 234098wB12_CPE0002665_assembly_filtered.pt: 1.0000
# 234098wB12_CPE0002665_assembly_filtered.pt vs 234098wD4_CPE0002596_assembly_filtered.pt: 0.9999
# 234098wB12_CPE0002665_assembly_filtered.pt vs 234098wE9_CPE0002644_assembly_filtered.pt: 1.0000
# 234098wB12_CPE0002665_assembly_filtered.pt vs 234098wF3_CPE0002590_assembly_filtered.pt: 0.9998
# 234098wB12_CPE0002665_assembly_filtered.pt vs 234098wG2_CPE0002583_assembly_filtered.pt: 0.9998
# 234098wB12_CPE0002665_assembly_filtered.pt vs 234098wG4_CPE0002599_assembly_filtered.pt: 0.9999
# 234098wB12_CPE0002665_assembly_filtered.pt vs 234099wC1_CPE0002671_assembly_filtered.pt: 0.9999
# 234098wB12_CPE0002665_assembly_filtered.pt vs 234099wF2_CPE0002684_assembly_filtered.pt: 0.9998
# 234098wB12_CPE0002665_assembly_filtered.pt vs 234099wH4_CPE0002706_assembly_filtered.pt: 0.9997
# 234098wD4_CPE0002596_assembly_filtered.pt vs 234098wA8_CPE0002631_assembly_filtered.pt: 0.9998
# 234098wD4_CPE0002596_assembly_filtered.pt vs 234098wB12_CPE0002665_assembly_filtered.pt: 0.9999
# 234098wD4_CPE0002596_assembly_filtered.pt vs 234098wD4_CPE0002596_assembly_filtered.pt: 1.0000
# 234098wD4_CPE0002596_assembly_filtered.pt vs 234098wE9_CPE0002644_assembly_filtered.pt: 0.9999
# 234098wD4_CPE0002596_assembly_filtered.pt vs 234098wF3_CPE0002590_assembly_filtered.pt: 0.9999
# 234098wD4_CPE0002596_assembly_filtered.pt vs 234098wG2_CPE0002583_assembly_filtered.pt: 0.9999
# 234098wD4_CPE0002596_assembly_filtered.pt vs 234098wG4_CPE0002599_assembly_filtered.pt: 0.9999
# 234098wD4_CPE0002596_assembly_filtered.pt vs 234099wC1_CPE0002671_assembly_filtered.pt: 0.9999
# 234098wD4_CPE0002596_assembly_filtered.pt vs 234099wF2_CPE0002684_assembly_filtered.pt: 0.9999
# 234098wD4_CPE0002596_assembly_filtered.pt vs 234099wH4_CPE0002706_assembly_filtered.pt: 0.9999
# 234098wE9_CPE0002644_assembly_filtered.pt vs 234098wA8_CPE0002631_assembly_filtered.pt: 0.9996
# 234098wE9_CPE0002644_assembly_filtered.pt vs 234098wB12_CPE0002665_assembly_filtered.pt: 1.0000
# 234098wE9_CPE0002644_assembly_filtered.pt vs 234098wD4_CPE0002596_assembly_filtered.pt: 0.9999
# 234098wE9_CPE0002644_assembly_filtered.pt vs 234098wE9_CPE0002644_assembly_filtered.pt: 1.0000
# 234098wE9_CPE0002644_assembly_filtered.pt vs 234098wF3_CPE0002590_assembly_filtered.pt: 0.9998
# 234098wE9_CPE0002644_assembly_filtered.pt vs 234098wG2_CPE0002583_assembly_filtered.pt: 0.9998
# 234098wE9_CPE0002644_assembly_filtered.pt vs 234098wG4_CPE0002599_assembly_filtered.pt: 0.9999
# 234098wE9_CPE0002644_assembly_filtered.pt vs 234099wC1_CPE0002671_assembly_filtered.pt: 0.9999
# 234098wE9_CPE0002644_assembly_filtered.pt vs 234099wF2_CPE0002684_assembly_filtered.pt: 0.9998
# 234098wE9_CPE0002644_assembly_filtered.pt vs 234099wH4_CPE0002706_assembly_filtered.pt: 0.9998
# 234098wF3_CPE0002590_assembly_filtered.pt vs 234098wA8_CPE0002631_assembly_filtered.pt: 0.9998
# 234098wF3_CPE0002590_assembly_filtered.pt vs 234098wB12_CPE0002665_assembly_filtered.pt: 0.9998
# 234098wF3_CPE0002590_assembly_filtered.pt vs 234098wD4_CPE0002596_assembly_filtered.pt: 0.9999
# 234098wF3_CPE0002590_assembly_filtered.pt vs 234098wE9_CPE0002644_assembly_filtered.pt: 0.9998
# 234098wF3_CPE0002590_assembly_filtered.pt vs 234098wF3_CPE0002590_assembly_filtered.pt: 1.0000
# 234098wF3_CPE0002590_assembly_filtered.pt vs 234098wG2_CPE0002583_assembly_filtered.pt: 0.9999
# 234098wF3_CPE0002590_assembly_filtered.pt vs 234098wG4_CPE0002599_assembly_filtered.pt: 0.9999
# 234098wF3_CPE0002590_assembly_filtered.pt vs 234099wC1_CPE0002671_assembly_filtered.pt: 0.9999
# 234098wF3_CPE0002590_assembly_filtered.pt vs 234099wF2_CPE0002684_assembly_filtered.pt: 0.9999
# 234098wF3_CPE0002590_assembly_filtered.pt vs 234099wH4_CPE0002706_assembly_filtered.pt: 0.9999
# 234098wG2_CPE0002583_assembly_filtered.pt vs 234098wA8_CPE0002631_assembly_filtered.pt: 0.9998
# 234098wG2_CPE0002583_assembly_filtered.pt vs 234098wB12_CPE0002665_assembly_filtered.pt: 0.9998
# 234098wG2_CPE0002583_assembly_filtered.pt vs 234098wD4_CPE0002596_assembly_filtered.pt: 0.9999
# 234098wG2_CPE0002583_assembly_filtered.pt vs 234098wE9_CPE0002644_assembly_filtered.pt: 0.9998
# 234098wG2_CPE0002583_assembly_filtered.pt vs 234098wF3_CPE0002590_assembly_filtered.pt: 0.9999
# 234098wG2_CPE0002583_assembly_filtered.pt vs 234098wG2_CPE0002583_assembly_filtered.pt: 1.0000
# 234098wG2_CPE0002583_assembly_filtered.pt vs 234098wG4_CPE0002599_assembly_filtered.pt: 0.9999
# 234098wG2_CPE0002583_assembly_filtered.pt vs 234099wC1_CPE0002671_assembly_filtered.pt: 0.9999
# 234098wG2_CPE0002583_assembly_filtered.pt vs 234099wF2_CPE0002684_assembly_filtered.pt: 1.0000
# 234098wG2_CPE0002583_assembly_filtered.pt vs 234099wH4_CPE0002706_assembly_filtered.pt: 0.9999
# 234098wG4_CPE0002599_assembly_filtered.pt vs 234098wA8_CPE0002631_assembly_filtered.pt: 0.9998
# 234098wG4_CPE0002599_assembly_filtered.pt vs 234098wB12_CPE0002665_assembly_filtered.pt: 0.9999
# 234098wG4_CPE0002599_assembly_filtered.pt vs 234098wD4_CPE0002596_assembly_filtered.pt: 0.9999
# 234098wG4_CPE0002599_assembly_filtered.pt vs 234098wE9_CPE0002644_assembly_filtered.pt: 0.9999
# 234098wG4_CPE0002599_assembly_filtered.pt vs 234098wF3_CPE0002590_assembly_filtered.pt: 0.9999
# 234098wG4_CPE0002599_assembly_filtered.pt vs 234098wG2_CPE0002583_assembly_filtered.pt: 0.9999
# 234098wG4_CPE0002599_assembly_filtered.pt vs 234098wG4_CPE0002599_assembly_filtered.pt: 1.0000
# 234098wG4_CPE0002599_assembly_filtered.pt vs 234099wC1_CPE0002671_assembly_filtered.pt: 0.9999
# 234098wG4_CPE0002599_assembly_filtered.pt vs 234099wF2_CPE0002684_assembly_filtered.pt: 0.9999
# 234098wG4_CPE0002599_assembly_filtered.pt vs 234099wH4_CPE0002706_assembly_filtered.pt: 0.9999
# 234099wC1_CPE0002671_assembly_filtered.pt vs 234098wA8_CPE0002631_assembly_filtered.pt: 0.9998
# 234099wC1_CPE0002671_assembly_filtered.pt vs 234098wB12_CPE0002665_assembly_filtered.pt: 0.9999
# 234099wC1_CPE0002671_assembly_filtered.pt vs 234098wD4_CPE0002596_assembly_filtered.pt: 0.9999
# 234099wC1_CPE0002671_assembly_filtered.pt vs 234098wE9_CPE0002644_assembly_filtered.pt: 0.9999
# 234099wC1_CPE0002671_assembly_filtered.pt vs 234098wF3_CPE0002590_assembly_filtered.pt: 0.9999
# 234099wC1_CPE0002671_assembly_filtered.pt vs 234098wG2_CPE0002583_assembly_filtered.pt: 0.9999
# 234099wC1_CPE0002671_assembly_filtered.pt vs 234098wG4_CPE0002599_assembly_filtered.pt: 0.9999
# 234099wC1_CPE0002671_assembly_filtered.pt vs 234099wC1_CPE0002671_assembly_filtered.pt: 1.0000
# 234099wC1_CPE0002671_assembly_filtered.pt vs 234099wF2_CPE0002684_assembly_filtered.pt: 0.9999
# 234099wC1_CPE0002671_assembly_filtered.pt vs 234099wH4_CPE0002706_assembly_filtered.pt: 1.0000
# 234099wF2_CPE0002684_assembly_filtered.pt vs 234098wA8_CPE0002631_assembly_filtered.pt: 0.9998
# 234099wF2_CPE0002684_assembly_filtered.pt vs 234098wB12_CPE0002665_assembly_filtered.pt: 0.9998
# 234099wF2_CPE0002684_assembly_filtered.pt vs 234098wD4_CPE0002596_assembly_filtered.pt: 0.9999
# 234099wF2_CPE0002684_assembly_filtered.pt vs 234098wE9_CPE0002644_assembly_filtered.pt: 0.9998
# 234099wF2_CPE0002684_assembly_filtered.pt vs 234098wF3_CPE0002590_assembly_filtered.pt: 0.9999
# 234099wF2_CPE0002684_assembly_filtered.pt vs 234098wG2_CPE0002583_assembly_filtered.pt: 1.0000
# 234099wF2_CPE0002684_assembly_filtered.pt vs 234098wG4_CPE0002599_assembly_filtered.pt: 0.9999
# 234099wF2_CPE0002684_assembly_filtered.pt vs 234099wC1_CPE0002671_assembly_filtered.pt: 0.9999
# 234099wF2_CPE0002684_assembly_filtered.pt vs 234099wF2_CPE0002684_assembly_filtered.pt: 1.0000
# 234099wF2_CPE0002684_assembly_filtered.pt vs 234099wH4_CPE0002706_assembly_filtered.pt: 0.9999
# 234099wH4_CPE0002706_assembly_filtered.pt vs 234098wA8_CPE0002631_assembly_filtered.pt: 0.9999
# 234099wH4_CPE0002706_assembly_filtered.pt vs 234098wB12_CPE0002665_assembly_filtered.pt: 0.9997
# 234099wH4_CPE0002706_assembly_filtered.pt vs 234098wD4_CPE0002596_assembly_filtered.pt: 0.9999
# 234099wH4_CPE0002706_assembly_filtered.pt vs 234098wE9_CPE0002644_assembly_filtered.pt: 0.9998
# 234099wH4_CPE0002706_assembly_filtered.pt vs 234098wF3_CPE0002590_assembly_filtered.pt: 0.9999
# 234099wH4_CPE0002706_assembly_filtered.pt vs 234098wG2_CPE0002583_assembly_filtered.pt: 0.9999
# 234099wH4_CPE0002706_assembly_filtered.pt vs 234098wG4_CPE0002599_assembly_filtered.pt: 0.9999
# 234099wH4_CPE0002706_assembly_filtered.pt vs 234099wC1_CPE0002671_assembly_filtered.pt: 1.0000
# 234099wH4_CPE0002706_assembly_filtered.pt vs 234099wF2_CPE0002684_assembly_filtered.pt: 0.9999
# 234099wH4_CPE0002706_assembly_filtered.pt vs 234099wH4_CPE0002706_assembly_filtered.pt: 1.0000
# C:\Users\yalin\AppData\Local\Temp\ipykernel_17036\860637376.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   emb = torch.load(file_path)

# %%
# Step 8: Cosine heatmap
plt.figure(figsize=(14, 12))
sns.heatmap(similarity_matrix, xticklabels=df_all['Header'], yticklabels=df_all['Header'], cmap='viridis')
plt.title("Cosine Similarity Heatmap")
plt.tight_layout()
plt.show()

# Step 9: DBSCAN clustering
clustering = DBSCAN(eps=0.1, min_samples=2, metric='cosine').fit(X)
df_all['Cluster'] = clustering.labels_

# Step 10: Similarity graph
threshold = 0.85
G = nx.Graph()
for i, label_i in enumerate(df_all['Header']):
    G.add_node(label_i)
    for j in range(i+1, len(df_all)):
        if similarity_matrix[i][j] >= threshold:
            G.add_edge(label_i, df_all['Header'][j], weight=similarity_matrix[i][j])

plt.figure(figsize=(14, 12))
pos = nx.spring_layout(G, seed=42)
nx.draw_networkx_nodes(G, pos, node_color='skyblue', node_size=500)
nx.draw_networkx_edges(G, pos, edge_color='gray')
nx.draw_networkx_labels(G, pos, font_size=6)
edge_labels = {(u, v): f"{d['weight']:.2f}" for u, v, d in G.edges(data=True)}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=5)
plt.title("Genome Similarity Graph (Cosine ≥ 0.85)")
plt.axis('off')
plt.tight_layout()
plt.show()

# Step 11: PCA visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
jitter = np.random.normal(0, 0.01, X_pca.shape)
X_pca_jittered = X_pca + jitter
unique_clusters = sorted(df_all['Cluster'].unique())
color_map = {cluster: plt.cm.tab10(i % 10) for i, cluster in enumerate(unique_clusters)}
colors = [color_map[c] for c in df_all['Cluster']]

plt.figure(figsize=(14, 12))
plt.scatter(X_pca_jittered[:,0], X_pca_jittered[:,1], c=colors)
for i, label in enumerate(df_all['Header']):
    plt.text(X_pca_jittered[i,0], X_pca_jittered[i,1], label, fontsize=5)
plt.title("PCA of Genome Embeddings with Clustering")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid(True)
plt.tight_layout()
plt.show()

# Step 12: Euclidean distance heatmap
distance_matrix = pairwise_distances(X, metric='euclidean')
plt.figure(figsize=(14, 12))
sns.heatmap(distance_matrix, xticklabels=df_all['Header'], yticklabels=df_all['Header'], cmap='coolwarm')
plt.title("Euclidean Distance Heatmap")
plt.tight_layout()
plt.show()
